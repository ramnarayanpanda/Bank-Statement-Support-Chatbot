# %%
import pandas as pd

# %%
df = pd.read_excel("/home/rampanda/Documents/DG Assist/data/bank_data/Bank Data Report Types.xlsx", sheet_name='AA')

# %%
df
# Out:
#      Unnamed: 0                                              Type1  \
# 0        Client                                                NaN
# 1   Description                                                NaN
# 2          Keys  headers\nbanks\n  - headers\n  - accounts\n   ...
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# ...

# %%
final_lst = []

for col in df.columns.tolist()[1:]:
    question = f"What all features are there in {col} report for Account Aggregator"
    answer = f"The features of Type1 report are:\n {df[col].iloc[1]} \n\n Keys included in Type1:\n {df[col].iloc[2]} \n\n The sample report link: {df[col].iloc[14]}"
    final_lst.append((question, answer))

# %%
final_lst
# Out:
# [('What all features are there in Type1 report for Account Aggregator',
#   'The features of Type1 report are:\n nan \n\n Keys included in Type1:\n headers\nbanks\n  - headers\n  - accounts\n          - customer_info\n          - headers\n          - transactions without category\n          - tamper_detection_details \n\n The sample report link: https://drive.google.com/file/d/1IUlmUVcjLvwkCcydn3vUPWip97Jceapk/view?usp=sharing'),
#  ('What all features are there in Type2 report for Account Aggregator',
#   'The features of Type1 report are:\n Type 1 report with each transactions contain category. \n\n Keys included in Type1:\n headers\nbanks\n  - headers\n  - accounts\n          - customer_info\n          - headers\n          - transactions with category\n          - tamper_detection_details\n          - fraud_analysis if tamper detection is BOTH or BOTH_2 \n\n The sample report link: https://drive.google.com/file/d/1ueMv4jHeHsHaEOowI66X0UG-3cx9qQVo/view?usp=sharing'),
# ...

# %%
pd.DataFrame(final_lst, columns=['question', 'answer']).to_excel("/home/rampanda/Documents/DG Assist/data/just_test1.xlsx", index=False)
